# %%
import pandas as pd
import numpy as np
import time
from tqdm import tqdm

from fbprophet import Prophet
from multiprocessing import Pool, cpu_count
# Out:
# Importing plotly failed. Interactive plots will not work.

# %%
df_train = (pd.read_csv('train.csv')
              .rename(columns={'date':'ds', 'sales':'y'}))

# %%
df_train.columns
# Out:
# Index(['ds', 'store', 'item', 'y'], dtype='object')

# %%
def rnd_timeseries(store, item):
    return df_train[(df_train.store==store)&(df_train.item==item)][['ds', 'y']]

# %%
ls_store_item = list(set(zip(df_train.store, df_train.item)))

# %%
# %%time
series = [rnd_timeseries(store, item) for store, item in ls_store_item]
# Out:
# CPU times: user 3.44 s, sys: 93.8 ms, total: 3.53 s
# Wall time: 3.52 s

# %%
def run_prophet(history_pd):
    model = Prophet(
        interval_width=0.95,
        growth='linear',
        daily_seasonality=False,
        weekly_seasonality=True,
        yearly_seasonality=True,
        seasonality_mode='multiplicative'
    )

    # fit the model
    model.fit(history_pd)

    # configure predictions
    future_pd = model.make_future_dataframe(
        periods=90,
        freq='d',
        include_history=True
    )

    # make predictions
    results_pd = model.predict(future_pd)
    return results_pd

# %%
# %%timeit
f = run_prophet(series[0])
# Out:
# INFO:numexpr.utils:NumExpr defaulting to 8 threads.
# 6.95 s ± 510 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %% [markdown]
# ## 1 hr 20 Mins

# %%
start_time = time.time()
result = list(map(lambda history_pd: run_prophet(history_pd), tqdm(series)))
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# 100%|██████████| 500/500 [1:20:37<00:00,  9.68s/it]
# --- 4837.546568393707 seconds ---

# %% [markdown]
# ## 44 Mins using multiprocessing

# %%
start_time = time.time()
p = Pool(cpu_count())
predictions = list(tqdm(p.imap(run_prophet, series), total=len(series)))
p.close()
p.join()
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# 100%|██████████| 500/500 [44:30<00:00,  5.34s/it]
# --- 2673.760531425476 seconds ---

# %% [markdown]
# ## 35 mins: With concurrent futures

# %%
import concurrent.futures

# %%
# %%time
with concurrent.futures.ProcessPoolExecutor() as executor:
    output = list(tqdm(executor.map(run_prophet, series), total=len(series)))
# Out:
# 100%|██████████| 500/500 [35:23<00:00,  4.25s/it]
# CPU times: user 4.67 s, sys: 2.75 s, total: 7.42 s
# Wall time: 35min 25s

# %% [markdown]
# ## 15 Mins: Using Ray

# %%
import ray
ray.init()

@ray.remote
def run_prophet(history_pd):
    model = Prophet(
        interval_width=0.95,
        growth='linear',
        daily_seasonality=False,
        weekly_seasonality=True,
        yearly_seasonality=True,
        seasonality_mode='multiplicative'
    )

    # fit the model
    model.fit(history_pd)

    # configure predictions
    future_pd = model.make_future_dataframe(
        periods=90,
        freq='d',
        include_history=True
    )

    # make predictions
    results_pd = model.predict(future_pd)
    return results_pd
# Out:
# 2020-08-24 23:29:08,286	INFO resource_spec.py:223 -- Starting Ray with 3.08 GiB memory available for workers and up to 1.55 GiB for objects. You can adjust these settings with ray.init(memory=<bytes>, object_store_memory=<bytes>).
# 2020-08-24 23:29:09,191	INFO services.py:1191 -- View the Ray dashboard at localhost:8265

# %%
# %%time
futures = ray.get([run_prophet.remote(i) for i in series])
# Out:
# (pid=8394) Importing plotly failed. Interactive plots will not work.
# (pid=8403) Importing plotly failed. Interactive plots will not work.
# (pid=8401) Importing plotly failed. Interactive plots will not work.
# (pid=8396) Importing plotly failed. Interactive plots will not work.
# (pid=8407) Importing plotly failed. Interactive plots will not work.
# (pid=8405) Importing plotly failed. Interactive plots will not work.
# (pid=8411) Importing plotly failed. Interactive plots will not work.
# (pid=8409) Importing plotly failed. Interactive plots will not work.
# (pid=8467) Importing plotly failed. Interactive plots will not work.
# (pid=8394) Initial log joint probability = -32.3947
# (pid=8394)     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
# (pid=8394)       99       3370.16   4.20642e-05       87.0329       0.485       0.485      124
# (pid=8394)     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
# (pid=8394)      106        3370.2   0.000156469       83.1894   1.536e-06       0.001      165  LS failed, Hessian reset
# (pid=8394)      148       3370.25   0.000258214       98.1808   1.945e-06       0.001      257  LS failed, Hessian reset
# (pid=8394)      199       3370.28   2.67403e-05       79.5758           1           1      333
# (pid=8394)     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
# (pid=8394)      222       3370.28   1.66973e-07       86.6703      0.7359      0.7359      362
# (pid=8394) Optimization terminated normally:
# (pid=8394)   Convergence detected: relative gradient magnitude is below tolerance
# (pid=8403) Initial log joint probability = -33.5263
# (pid=8403)     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
# (pid=8403)       97       3545.15   0.000115893       74.2724   1.387e-06       0.001      157  LS failed, Hessian reset
# (pid=8403)       99       3545.16   3.15165e-05        78.957      0.8099      0.8099      159
# (pid=8403)     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
# (pid=8401) Initial log joint probability = -28.0701
# (pid=8401)     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
# (pid=8403)      178       3545.17    1.0839e-06       83.1999   1.291e-08       0.001      290  LS failed, Hessian reset
# (pid=8403)      184       3545.17   1.84707e-07       74.7966       0.957       0.957      300
# (pid=8403) Optimization terminated normally:
# (pid=8403)   Convergence detected: relative gradient magnitude is below tolerance
# (pid=8401)       90       4176.82   0.000147766       122.643   1.351e-06       0.001      160  LS failed, Hessian reset
# (pid=8401)       99       4176.84   2.04183e-05       63.8505           1           1      170
# (pid=8401)     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
# (pid=8445) Importing plotly failed. Interactive plots will not work.
# (pid=8510) Importing plotly failed. Interactive plots will not work.
# (pid=8401)      134       4176.85   1.96209e-07       71.6584      0.5214      0.5214      213
# (pid=8401) Optimization terminated normally:
# (pid=8401)   Convergence detected: relative gradient magnitude is below tolerance
# (pid=8476) Importing plotly failed. Interactive plots will not work.
# (pid=8529) Importing plotly failed. Interactive plots will not work.
# (pid=8499) Importing plotly failed. Interactive plots will not work.
# (pid=8407) Initial log joint probability = -27.9777
# (pid=8407)     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
# (pid=8396) Initial log joint probability = -15.7248
# (pid=8396)     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
# (pid=8405) Initial log joint probability = -38.7425
# (pid=8405)     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
# (pid=8407)       99        4304.2   2.64786e-05       78.9902      0.7415      0.7415      139
# (pid=8407)     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
# (pid=8396)       83       4129.73   0.000862824       312.321   1.037e-05       0.001      151  LS failed, Hessian reset
# (pid=8407)      116        4304.2   1.87317e-07       72.1699     0.06386           1      164
# (pid=8407) Optimization terminated normally:
# (pid=8407)   Convergence detected: relative gradient magnitude is below tolerance
# (pid=8405)       58       3731.81    0.00160504       231.175   1.935e-05       0.001      105  LS failed, Hessian reset
# (pid=8396)       99       4129.85   8.79837e-05       88.8107       0.579       0.579      171
# (pid=8396)     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
# (pid=8396)      103       4129.88   0.000125782        53.291   1.727e-06       0.001      215  LS failed, Hessian reset
# (pid=8405)       85       3732.13   0.000289738       147.532   3.181e-06       0.001      175  LS failed, Hessian reset
# (pid=8405)       99       3732.23   0.000310843       60.8704           1           1      191
# (pid=8405)     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
# (pid=8409) Initial log joint probability = -31.3472
# (pid=8409)     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
# (pid=8396)      153       4129.89   3.14731e-07       65.9014           1           1      289
# (pid=8396) Optimization terminated normally:
# (pid=8396)   Convergence detected: relative gradient magnitude is below tolerance
# (pid=8411) Initial log joint probability = -31.6705
# (pid=8411)     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
# (pid=8409)       99       4161.77   0.000249036       59.0402      0.9051      0.9051      139
# (pid=8409)     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
# (pid=8405)      184       3733.16   0.000194443        104.63   1.336e-06       0.001      337  LS failed, Hessian reset
# (pid=8405)      199        3733.2   1.52697e-05       73.5605      0.1062      0.2783      358
# (pid=8405)     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
# (pid=
# (pid=8510)     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
# (pid=8510)       92       3520.63   0.000212903       70.6128   4.233e-06       0.001      173  LS failed, Hessian reset
# (pid=8510)       99       3520.64    9.5583e-05       51.5256           1           1      182
# (pid=8510)     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
# (pid=8405) Initial log joint probability = -26.9328
# (pid=8405)     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
# (pid=8510)      158       3520.67   1.52055e-05       63.1578   2.179e-07       0.001      303  LS failed, Hessian reset
# (pid=8405)       56       3958.35   0.000183582       82.0633   2.164e-06       0.001      110  LS failed, Hessian reset
# (pid=8510)      199       3520.68   4.93234e-07       58.1624      0.3786           1      359
# (pid=8510)     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
# (pid=8405)       99       3958.36   8.56017e-08       70.3748      0.3285      0.3285      165
# (pid=8405)     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
# (pid=8405)      101       3958.36   1.28256e-07       61.1073      0.3784           1      168
# (pid=8405) Optimization terminated normally:
# (pid=8405)   Convergence detected: relative gradient magnitude is below tolerance
# (pid=8510)      252       3520.68   5.61067e-07       49.5791      0.2122           1      430
# (pid=8510) Optimization terminated normally:
# (pid=8510)   Convergence detected: relative gradient magnitude is below tolerance
# (pid=8396) Initial log joint probability = -24.7631
# (pid=8396)     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
# (pid=8394) Initial log joint probability = -29.9541
# (pid=8394)     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
# (pid=8396)       80       4150.72   0.000185707       123.783   1.556e-06       0.001      144  LS failed, Hessian reset
# (pid=8396)       99       4150.77   1.40213e-05       75.7856           1           1      169
# (pid=8396)     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
# (pid=8394)       99       4293.27   0.000269558       66.0898           1           1      144
# (pid=8394)     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
# (pid=8396)      155       4150.82   0.000213167       101.992   3.181e-06       0.001      270  LS failed, Hessian reset
# (pid=8476) Initial log joint probability = -35.0403
# (pid=8476)     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
# (pid=8394)      125        4293.5   0.000253815       193.711   3.073e-06       0.001      211  LS failed, Hessian reset
# (pid=8396)      199       4150.83   1.72522e-05       89.9102           1           1      327
# (pid=8396)     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
# (pid=8396)      203       4150.83   1.10311e-05       81.2365   1.286e-07       0.001      378  LS failed, Hessian reset
# (pid=8476)       99       3469.98   0.000203564       53.0098           1           1      120
# (pid=8476)     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
# (pid=8396)      241       4150.83   4.12835e-07       80.1198      0.2393      0.9429      424
# (pid=8396) Optimization terminated normally:
# (pid=8396)   Convergence detected: relative gradient magnitude is below tolerance
# (pid=8394)      164       4293.53   7.61993e-06        74.745   9.379e-08       0.001      305  LS failed, Hessian reset
# (pid=8394)      177       4293.53   1.59281e-07        62.802      0.1975           1      324
# (pid=8394) Optimization terminated normally:
# (pid=8394)   Convergence detected: relative gradient magnitude is below tolerance
# (pid=8476)      189       3470.06   0.000179761       55.3522   4.605e-06       0.001      285  LS failed, Hessian reset
# (pid=8476)      199       3470.07   2.07114e-05       34.4531           1           1      303
# (pid=8476)     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
# (pid=8476)      202       3470.07     1.812e-05       47.1678    3.97e-07       0.001      341  LS failed, Hessian reset
# (pid=8476)      230       3470.07   1.82265e-07       42.4624      0.2234     0.02234      387
# (pid=8476) Optimization terminated normally:
# (pid=8476)   Convergence detected: relative gradient magnitude is below tolerance
# (pid=8407) Initial log joint probability = -28.009
# (pid=8407)     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
# (pid=8407)       99       3953.91   0.000119753       77.4167      0.3526           1      132
# (pid=8407)     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
# (pid=8407)      112       3953.97   0.000241187        166.88   3.228e-06       0.001      192  LS failed, Hessian reset
# (pid=8407)      199       3954.02   0.000327218       69.2807           1           1      309
# (pid=8407)     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
# (pid=8407)      299       3954.42   6.89412e-07       68.8632      0.3891      0.3891      427
# (pid=8407)     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
# (pid=8407)      318       3954.42   3.89673e-07       73.9839           1           1      451
# (pid=8407) Optimization terminated normally:
# (pid=8407)   Convergence detected: relative gradient magnitude is below tolerance
# CPU times: user 17.8 s, sys: 7.58 s, total: 25.4 s
# Wall time: 15min 11s

# %%
len(futures[498])
# Out:
# 1916
